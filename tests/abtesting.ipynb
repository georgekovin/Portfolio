# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.stats.proportion import proportions_ztest

# %%
ab_data = pd.read_csv('data/ab_data.zip')

ab_data
# Out:
#         user_id   timestamp group  converted
# 0        851104  2017-01-21     A          0
# 1        804228  2017-01-12     A          0
# 2        661590  2017-01-11     B          0
# 3        853541  2017-01-08     B          0
# 4        864975  2017-01-21     A          1
# ...         ...         ...   ...        ...
# 290477   751197  2017-01-03     A          0
# 290478   945152  2017-01-12     A          0
# 290479   734608  2017-01-22     A          0
# 290480   697314  2017-01-15     A          0
# 290481   715931  2017-01-16     B          0
#
# [290482 rows x 4 columns]

# %%
ab_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290482 entries, 0 to 290481
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   user_id    290482 non-null  int64
#  1   timestamp  290482 non-null  object
#  2   group      290482 non-null  object
#  3   converted  290482 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 8.9+ MB

# %%
ab_data['timestamp'] = pd.to_datetime(ab_data['timestamp'])
ab_data['group'] = ab_data['group'].astype('category')

ab_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290482 entries, 0 to 290481
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   user_id    290482 non-null  int64
#  1   timestamp  290482 non-null  datetime64[ns]
#  2   group      290482 non-null  category
#  3   converted  290482 non-null  int64
# dtypes: category(1), datetime64[ns](1), int64(2)
# memory usage: 6.9 MB

# %%
daily_data = ab_data.groupby(['timestamp','group']).agg({
    'user_id':'count',
    'converted':'sum'
}).reset_index().rename(columns={'user_id': 'users_count'})

daily_data
# Out:
#     timestamp group  users_count  converted
# 0  2017-01-02     A         2851        357
# 1  2017-01-02     B         2848        339
# 2  2017-01-03     A         6584        749
# 3  2017-01-03     B         6620        754
# 4  2017-01-04     A         6573        797
# 5  2017-01-04     B         6538        763
# 6  2017-01-05     A         6419        791
# 7  2017-01-05     B         6509        743
# 8  2017-01-06     A         6604        762
# 9  2017-01-06     B         6735        834
# 10 2017-01-07     A         6595        793
# 11 2017-01-07     B         6604        765
# 12 2017-01-08     A         6692        793
# 13 2017-01-08     B         6702        810
# 14 2017-01-09     A         6624        792
# 15 2017-01-09     B         6619        783
# 16 2017-01-10     A         6657        752
# 17 2017-01-10     B         6690        844
# 18 2017-01-11     A         6686        790
# 19 2017-01-11     B         6672        772
# 20 2017-01-12     A         6508        794
# 21 2017-01-12     B         6631        815
# 22 2017-01-13     A         6562        769
# 23 2017-01-13     B         6510        730
# 24 2017-01-14     A         6555        830
# 25 2017-01-14     B         6607        791
# 26 2017-01-15     A         6710        814
# 27 2017-01-15     B         6556        743
# 28 2017-01-16     A         6604        801
# 29 2017-01-16     B         6526        779
# 30 2017-01-17     A         6606        816
# 31 2017-01-17     B         6527        828
# 32 2017-01-18     A         6484        807
# 33 2017-01-18     B         6602        814
# 34 2017-01-19     A         6562        787
# 35 2017-01-19     B         6555        758
# 36 2017-01-20     A         6536        752
# 37 2017-01-20     B         6690        786
# 38 2017-01-21     A         6765        851
# 39 2017-01-21     B         6544        757
# 40 2017-01-22     A         6587        782
# 41 2017-01-22     B         6649        782
# 42 2017-01-23     A         6717        847
# 43 2017-01-23     B         6627        802
# 44 2017-01-24     A         3760        441
# 45 2017-01-24     B         3680        446

# %%
data_piv = daily_data.copy()

data_piv['conversion'] = daily_data['converted'] / daily_data['users_count'] * 100

data_piv
# Out:
#     timestamp group  users_count  converted  conversion
# 0  2017-01-02     A         2851        357   12.521922
# 1  2017-01-02     B         2848        339   11.903090
# 2  2017-01-03     A         6584        749   11.376063
# 3  2017-01-03     B         6620        754   11.389728
# 4  2017-01-04     A         6573        797   12.125361
# 5  2017-01-04     B         6538        763   11.670236
# 6  2017-01-05     A         6419        791   12.322792
# 7  2017-01-05     B         6509        743   11.414964
# 8  2017-01-06     A         6604        762   11.538462
# 9  2017-01-06     B         6735        834   12.383073
# 10 2017-01-07     A         6595        793   12.024261
# 11 2017-01-07     B         6604        765   11.583889
# 12 2017-01-08     A         6692        793   11.849970
# 13 2017-01-08     B         6702        810   12.085944
# 14 2017-01-09     A         6624        792   11.956522
# 15 2017-01-09     B         6619        783   11.829582
# 16 2017-01-10     A         6657        752   11.296380
# 17 2017-01-10     B         6690        844   12.615845
# 18 2017-01-11     A         6686        790   11.815734
# 19 2017-01-11     B         6672        772   11.570743
# 20 2017-01-12     A         6508        794   12.200369
# 21 2017-01-12     B         6631        815   12.290756
# 22 2017-01-13     A         6562        769   11.718988
# 23 2017-01-13     B         6510        730   11.213518
# 24 2017-01-14     A         6555        830   12.662090
# 25 2017-01-14     B         6607        791   11.972151
# 26 2017-01-15     A         6710        814   12.131148
# 27 2017-01-15     B         6556        743   11.333130
# 28 2017-01-16     A         6604        801   12.129013
# 29 2017-01-16     B         6526        779   11.936868
# 30 2017-01-17     A         6606        816   12.352407
# 31 2017-01-17     B         6527        828   12.685767
# 32 2017-01-18     A         6484        807   12.446021
# 33 2017-01-18     B         6602        814   12.329597
# 34 2017-01-19     A         6562        787   11.993295
# 35 2017-01-19     B         6555        758   11.563692
# 36 2017-01-20     A         6536        752   11.505508
# 37 2017-01-20     B         6690        786   11.748879
# 38 2017-01-21     A         6765        851   12.579453
# 39 2017-01-21     B         6544        757   11.567848
# 40 2017-01-22     A         6587        782   11.871869
# 41 2017-01-22     B         6649        782   11.761167
# 42 2017-01-23     A         6717        847   12.609796
# 43 2017-01-23     B         6627        802   12.102007
# 44 2017-01-24     A         3760        441   11.728723
# 45 2017-01-24     B         3680        446   12.119565

# %%
data_piv[data_piv['timestamp'] == '2017-01-05'][data_piv['group'] == 'A']['conversion'].round(2)
# Out:
# C:\Users\honor\AppData\Local\Temp\ipykernel_1068\1583281862.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_piv[data_piv['timestamp'] == '2017-01-05'][data_piv['group'] == 'A']['conversion'].round(2)
# 6    12.32
# Name: conversion, dtype: float64

# %%
fig = plt.figure(figsize=(8, 4))
ax = fig.add_axes([1, 1, 1, 1])

# %%
sns.boxplot(data=data_piv, 
            x='conversion', 
            y='group')
# Out:
# <AxesSubplot: xlabel='conversion', ylabel='group'>

# %%
conversion_piv = data_piv.groupby('group')['conversion'].agg(['mean', 'median'])

conversion_piv
# Out:
#             mean     median
# group
# A      12.032876  12.024261
# B      11.872697  11.829582

# %%
conversion_piv['mean'] - conversion_piv['median']
# Out:
# group
# A    0.008615
# B    0.043116
# dtype: float64

# %%
sns.lineplot(data=data_piv,
             x='timestamp', 
             y='conversion',
             hue='group')
# Out:
# <AxesSubplot: xlabel='timestamp', ylabel='conversion'>

# %%
daily_data['cum_users_count'] = daily_data.groupby(['group'])['users_count'].cumsum()

daily_data['cum_converted'] = daily_data.groupby(['group'])['converted'].cumsum()

daily_data['cum_conversion'] = daily_data['cum_converted']/daily_data['cum_users_count'] * 100

daily_data
# Out:
#     timestamp group  users_count  converted  cum_users_count  cum_converted  \
# 0  2017-01-02     A         2851        357             2851            357
# 1  2017-01-02     B         2848        339             2848            339
# 2  2017-01-03     A         6584        749             9435           1106
# 3  2017-01-03     B         6620        754             9468           1093
# 4  2017-01-04     A         6573        797            16008           1903
# 5  2017-01-04     B         6538        763            16006           1856
# 6  2017-01-05     A         6419        791            22427           2694
# 7  2017-01-05     B         6509        743            22515           2599
# 8  2017-01-06     A         6604        762            29031           3456
# 9  2017-01-06     B         6735        834            29250           3433
# 10 2017-01-07     A         6595        793            35626           4249
# 11 2017-01-07     B         6604        765            35854           4198
# 12 2017-01-08     A         6692        793            42318           5042
# 13 2017-01-08     B         6702        810            42556           5008
# 14 2017-01-09     A         6624        792            48942           5834
# 15 2017-01-09     B         6619        783            49175           5791
# 16 2017-01-10     A         6657        752            55599           6586
# 17 2017-01-10     B         6690        844            55865           6635
# 18 2017-01-11     A         6686        790            62285           7376
# 19 2017-01-11     B         6672        772            62537           7407
# 20 2017-01-12     A         6508        794            68793           8170
# 21 2017-01-12     B         6631        815            69168           8222
# 22 2017-01-13     A         6562        769            75355           8939
# 23 2017-01-13     B         6510        730            75678           8952
# 24 2017-01-14     A         6555        830            81910           9769
# 25 2017-01-14     B         6607        791            82285           9743
# 26 2017-01-15     A         6710        814            88620          10583
# 27 2017-01-15     B         6556        743            88841          10486
# 28 2017-01-16     A         6604        801            95224          11384
# 29 2017-01-16     B         6526        779            95367          11265
# 30 2017-01-17     A         6606        816           101830          12200
# 31 2017-01-17     B         6527        828           101894          12093
# 32 2017-01-18     A         6484        807           108314          13007
# 33 2017-01-18     B         6602        814           108496          12907
# 34 2017-01-19     A         6562        787           114876          13794
# 35 2017-01-19     B         6555        758           115051          13665
# 36 2017-01-20     A         6536        752           121412          14546
# 37 2017-01-20     B         6690        786           121741          14451
# 38 2017-01-21     A         6765        851           128177          15397
# 39 2017-01-21     B         6544        757           128285          15208
# 40 2017-01-22     A         6587        782           134764          16179
# 41 2017-01-22     B         6649        782           134934          15990
# 42 2017-01-23     A         6717        847           141481          17026
# 43 2017-01-23     B         6627        802           141561          16792
# 44 2017-01-24     A         3760        441           145241          17467
# 45 2017-01-24     B         3680        446           145241          17238
#
#     cum_conversion
# 0        12.521922
# 1        11.903090
# 2        11.722311
# 3        11.544149
# 4        11.887806
# 5        11.595652
# 6        12.012307
# 7        11.543416
# 8        11.904516
# 9        11.736752
# 10       11.926683
# 11       11.708596
# 12       11.914552
# 13       11.768023
# 14       11.920232
# 15       11.776309
# 16       11.845537
# 17       11.876846
# 18       11.842338
# 19       11.844188
# 20       11.876208
# 21       11.887000
# 22       11.862517
# 23       11.829065
# 24       11.926505
# 25       11.840554
# 26       11.942000
# 27       11.803109
# 28       11.954969
# 29       11.812262
# 30       11.980752
# 31       11.868216
# 32       12.008605
# 33       11.896291
# 34       12.007730
# 35       11.877341
# 36       11.980694
# 37       11.870282
# 38       12.012295
# 39       11.854854
# 40       12.005432
# 41       11.850238
# 42       12.034125
# 43       11.862024
# 44       12.026218
# 45       11.868550

# %%
sns.lineplot(data=daily_data, 
             x='timestamp', 
             y='cum_conversion', 
             hue='group')
# Out:
# <AxesSubplot: xlabel='timestamp', ylabel='cum_conversion'>

# %%
sample_a = pd.read_csv('data/ab_test-redesign_sample_a.zip')
sample_b = pd.read_csv('data/ab_test-redesign_sample_b.zip')

# %%
sample_a['date'] = pd.to_datetime(sample_a['date'])

sampiv_a = sample_a.groupby('date', as_index=False).agg({'cid': 'count', 
                                                         'transactions': 'sum', 
                                                         'revenue': 'sum'})

sampiv_a
# Out:
#          date   cid  transactions  revenue
# 0  2020-11-06  2576            16  1577279
# 1  2020-11-07  2704            23  1721886
# 2  2020-11-08  3354            25   846051
# 3  2020-11-09  3234            18   708830
# 4  2020-11-10  3022            29   826984
# 5  2020-11-11  3218            19  1209656
# 6  2020-11-12  3467            19   607839
# 7  2020-11-13  3676            36  1338816
# 8  2020-11-14  3372            30  2659277
# 9  2020-11-15  3881            27  1189970
# 10 2020-11-16  4766            30  4213774
# 11 2020-11-17  4309            21  1779293
# 12 2020-11-18  3718            20   939301
# 13 2020-11-19  3234            26  2166766
# 14 2020-11-20  3168            25  1119974
# 15 2020-11-21  3116            18   939670
# 16 2020-11-22  3298            33  1205426
# 17 2020-11-23  3458            26   858274

# %%
sampiv_a[sampiv_a['date'] == '2020-11-08']
# Out:
#         date   cid  transactions  revenue
# 2 2020-11-08  3354            25   846051

# %%
sample_b['date'] = pd.to_datetime(sample_b['date'])

sampiv_b = sample_b.groupby('date', as_index=False).agg({'cid': 'count', 
                                                         'transactions': 'sum', 
                                                         'revenue': 'sum'})

sampiv_b
# Out:
#          date   cid  transactions  revenue
# 0  2020-11-06  2499            19   996645
# 1  2020-11-07  2804            19   555499
# 2  2020-11-08  3291            24  3044842
# 3  2020-11-09  3062            25  1285836
# 4  2020-11-10  3072            30  2414726
# 5  2020-11-11  3208            22  3555727
# 6  2020-11-12  3494            25   915653
# 7  2020-11-13  3606            37  1703475
# 8  2020-11-14  3276            34  2369998
# 9  2020-11-15  3919            27  1147144
# 10 2020-11-16  4883            27  1553700
# 11 2020-11-17  4313            26  1069200
# 12 2020-11-18  3710            18  2100459
# 13 2020-11-19  3171            29  2770174
# 14 2020-11-20  3075            15  1019850
# 15 2020-11-21  3129            22  2586267
# 16 2020-11-22  3378            34  1779841
# 17 2020-11-23  3493            30  1585306

# %%
sampiv_a['cumcid'] = sampiv_a['cid'].cumsum()

sampiv_a['cumtrans'] = sampiv_a['transactions'].cumsum()

sampiv_a['cumrev'] = sampiv_a['revenue'].cumsum()

sampiv_a['cumconv'] = sampiv_a['cumtrans'] / sampiv_a['cumcid'] * 100

sampiv_a['cumcheck'] = sampiv_a['cumrev'] / sampiv_a['cumtrans']

sampiv_a

sampiv_a['cumconv'].mean().round(2)
# Out:
# 0.71

# %%
sampiv_b['cumcid'] = sampiv_b['cid'].cumsum()

sampiv_b['cumtrans'] = sampiv_b['transactions'].cumsum()

sampiv_b['cumrev'] = sampiv_b['revenue'].cumsum()

sampiv_b['cumconv'] = sampiv_b['cumtrans'] / sampiv_b['cumcid'] * 100

sampiv_b['cumcheck'] = sampiv_b['cumrev'] / sampiv_b['cumtrans']

sampiv_b

sampiv_b['cumconv'].mean().round(2)
# Out:
# 0.76

# %%
sampiv_a
# Out:
#          date   cid  transactions  revenue  cumcid  cumtrans    cumrev  \
# 0  2020-11-06  2576            16  1577279    2576        16   1577279
# 1  2020-11-07  2704            23  1721886    5280        39   3299165
# 2  2020-11-08  3354            25   846051    8634        64   4145216
# 3  2020-11-09  3234            18   708830   11868        82   4854046
# 4  2020-11-10  3022            29   826984   14890       111   5681030
# 5  2020-11-11  3218            19  1209656   18108       130   6890686
# 6  2020-11-12  3467            19   607839   21575       149   7498525
# 7  2020-11-13  3676            36  1338816   25251       185   8837341
# 8  2020-11-14  3372            30  2659277   28623       215  11496618
# 9  2020-11-15  3881            27  1189970   32504       242  12686588
# 10 2020-11-16  4766            30  4213774   37270       272  16900362
# 11 2020-11-17  4309            21  1779293   41579       293  18679655
# 12 2020-11-18  3718            20   939301   45297       313  19618956
# 13 2020-11-19  3234            26  2166766   48531       339  21785722
# 14 2020-11-20  3168            25  1119974   51699       364  22905696
# 15 2020-11-21  3116            18   939670   54815       382  23845366
# 16 2020-11-22  3298            33  1205426   58113       415  25050792
# 17 2020-11-23  3458            26   858274   61571       441  25909066
#
#      cumconv      cumcheck
# 0   0.621118  98579.937500
# 1   0.738636  84593.974359
# 2   0.741256  64769.000000
# 3   0.690934  59195.682927
# 4   0.745467  51180.450450
# 5   0.717915  53005.276923
# 6   0.690614  50325.671141
# 7   0.732644  47769.410811
# 8   0.751144  53472.641860
# 9   0.744524  52423.917355
# 10  0.729809  62133.683824
# 11  0.704683  63753.088737
# 12  0.690995  62680.370607
# 13  0.698523  64264.666667
# 14  0.704076  62927.736264
# 15  0.696890  62422.424084
# 16  0.714126  60363.354217
# 17  0.716246  58750.716553

# %%
fig = plt.figure(figsize=(8, 4))

ax = fig.add_axes([1, 1, 1, 1])

sns.lineplot(data=sampiv_a, 
             x='date', 
             y='cumconv')

sns.lineplot(data=sampiv_b, 
             x='date', 
             y='cumconv')
# Out:
# <Axes: xlabel='date', ylabel='cumconv'>

# %%
sns.lineplot(data=sampiv_a, 
             x='date', 
             y='cumcheck')

sns.lineplot(data=sampiv_b, 
             x='date', 
             y='cumcheck')
# Out:
# <AxesSubplot: xlabel='date', ylabel='cumcheck'>

# %%
converted_piv= ab_data.groupby('group')['converted'].agg(['sum', 'count'])

converted_piv
# Out:
#          sum   count
# group
# A      17467  145241
# B      17238  145241

# %%
H0 = 'Конверсии в группах А и B равны'
H1 = 'Конверсия в группе А выше, чем конверсия в группе B'
alpha = 0.05 

_, pvalue = proportions_ztest(
    count=converted_piv['sum'], #число "успехов"
    nobs=converted_piv['count'], #общее число наблюдений
    alternative='larger',
)


print('p-value: ', round(pvalue, 2))

if pvalue < alpha: 
    print("Отвергаем нулевую гипотезу. {}".format(H0))
    print("Альтернативная гипотеза. H1: {}".format(H1))
else:
    print("Принимаем нулевую гипотезу. {}".format(H0))
# Out:
# p-value:  0.1
# Принимаем нулевую гипотезу. Конверсии в группах А и B равны

# %%
from modules.cumcalc import get_cumseries

samp_ab = pd.concat([sample_a, sample_b])
 

get_cumseries(data=samp_ab, cols=['cid', 'transactions', 'revenue'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 from modules.cumcalc import get_cumseries
#       3 samp_ab = pd.concat([sample_a, sample_b])
#       6 get_cumseries(data=samp_ab, cols=['cid', 'transactions', 'revenue'])
#
# ModuleNotFoundError: No module named 'modules'
