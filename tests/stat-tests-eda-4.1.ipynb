# %% [markdown]
# # Установка библиотек

# %%
import pandas as pd #для работы с таблицами

# %% [markdown]
# Для автоматического применения статистического критерия (теста) используется модуль `stats` библиотеки `scipy`.
#
# Этот модуль содержит большое количество вероятностных распределений, корреляционные функции и статистические тесты и многое другое.
#
# Также активно используется библиотека `statsmodels`
#
# Для установки библиотеки `scipy` и `statsmodels` можно воспользоваться менеджером пакетов `pip`.

# %% [markdown]
# # Загрузка данных

# %% [markdown]
# Для скачивания данных используем команду `!wget`.
#
# Данные появятся в локальной директории.
#
# Мы будем использовать информацию о диаметре пицц разных производителей.

# %% [markdown]
# Загрузим данные в память ноутбука.

# %%
data = pd.read_csv('https://raw.githubusercontent.com/harika-bonthu/Hypothesis-test-examples/main/pizzas.csv')

# %%
data.rename(columns={'Making Unit 1': 'Пиццерия №1', 'Making Unit 2': 'Пиццерия №2'}, inplace=True)

# %%
data.dtypes == 'float'
# Out:
# Пиццерия №1    True
# Пиццерия №2    True
# dtype: bool

# %%
data

# НП - две пиццерии - столбцы
# ЗП - диаметры пицц - строки
# Out:
#     Пиццерия №1  Пиццерия №2
# 0        6.8090       6.7703
# 1        6.4376       7.5093
# 2        6.9157       6.7300
# 3        7.3012       6.7878
# 4        7.4488       7.1522
# 5        7.3871       6.8110
# 6        6.8755       7.2212
# 7        7.0621       6.6606
# 8        6.6840       7.2402
# 9        6.8236       7.0503
# 10       7.3930       6.8810
# 11       7.5169       7.4059
# 12       6.9246       6.7652
# 13       6.9256       6.0380
# 14       6.5797       7.1581
# 15       6.8394       7.0240
# 16       6.5970       6.6672
# 17       7.2705       7.4314
# 18       7.2828       7.3070
# 19       7.3495       6.7478
# 20       6.9438       6.8889
# 21       7.1560       7.4220
# 22       6.5341       6.5217
# 23       7.2854       7.1688
# 24       6.9952       6.7594
# 25       6.8568       6.9399
# 26       7.2163       7.0133
# 27       6.6801       6.9182
# 28       6.9431       6.3346
# 29       7.0852       7.5459
# 30       6.7794       7.0992
# 31       7.2783       7.1180
# 32       7.1561       6.6965
# 33       7.3943       6.5780
# 34       6.9405       7.3875

# %%
data.iloc[:, 1]
# Out:
# 0     6.7703
# 1     7.5093
# 2     6.7300
# 3     6.7878
# 4     7.1522
# 5     6.8110
# 6     7.2212
# 7     6.6606
# 8     7.2402
# 9     7.0503
# 10    6.8810
# 11    7.4059
# 12    6.7652
# 13    6.0380
# 14    7.1581
# 15    7.0240
# 16    6.6672
# 17    7.4314
# 18    7.3070
# 19    6.7478
# 20    6.8889
# 21    7.4220
# 22    6.5217
# 23    7.1688
# 24    6.7594
# 25    6.9399
# 26    7.0133
# 27    6.9182
# 28    6.3346
# 29    7.5459
# 30    7.0992
# 31    7.1180
# 32    6.6965
# 33    6.5780
# 34    7.3875
# Name: Пиццерия №2, dtype: float64

# %% [markdown]
# # Проверка данных на нормальность

# %%
H0 = 'Данные распределены нормально'
Ha = 'Данные не распределены нормально (мы отвергаем H0)'

# %% [markdown]
# Установим уровень значимости

# %%
alpha = 0.05

# %% [markdown]
# ## Тест Шапиро-Уилка

# %%
from scipy.stats import shapiro

# %%
_, p = shapiro(data)
print('p=%.3f' % p)

# Интерпретация 

if p > alpha:
	print(H0)
else:
	print(Ha)
# Out:
# p=0.204
# Данные распределены нормально

# %%
pp = shapiro(data)

pv = round(pp.pvalue, 3)

print(f'p={pv}')

if pv > alpha:
	print(H0)
else:
	print(Ha)
# Out:
# p=0.204
# Данные распределены нормально

# %% [markdown]
# ## Тест Д’Агостино

# %%
from scipy.stats import normaltest

# %%
_, p = normaltest(data)
#normaltest возвращает двустороннюю вероятность для проверки гипотезы

print('p=%.3f' % p[0])

# Интерпретация 

if p[0] > alpha/2:
	print(H0)
else:
	print(Ha)
# Out:
# p=0.251
# Данные распределены нормально

# %%
pp = normaltest(data)

pp
# Out:
# NormaltestResult(statistic=array([2.76116448, 1.22847999]), pvalue=array([0.25143212, 0.54105194]))

# %% [markdown]
# # Независимый T-тест

# %%
from scipy.stats import ttest_ind

# %%
H0 = 'Нет значимой разницы между диаметрами пиццы в разных пиццериях.'
Ha = 'Есть значимая разница между диаметрами пиццы в разных пиццериях.'

# %% [markdown]
# Зависимая переменная (диаметр пиццы) является количественной. Группы происходят из разных совокупностей. Следовательно, мы используем независимый T-тест.

# %%
def t_test(df):
    print('\n' + "*** Результаты независимого T-теста ***")
    test_results = ttest_ind(data['Пиццерия №1'], data['Пиццерия №2'], equal_var=True)

    p = round(test_results[1],2)

    if p>alpha:
        print(f"{p} > {alpha}. Мы не можем отвергнуть нулевую гипотезу. {H0}")
    else:
        print(f"{p} <= {alpha}. Мы отвергаем нулевую гипотезу. {Ha}")

t_test(data)
# Out:
# *** Результаты независимого T-теста ***
# 0.47 > 0.05. Мы не можем отвергнуть нулевую гипотезу. Нет значимой разницы между диаметрами пиццы в разных пиццериях.

# %% [markdown]
# -----

# %% [markdown]
# # Корреляция Спирмана

# %%
from numpy.random import rand
from scipy.stats import spearmanr

data1 = rand(1000) * 20
data2 = data1 + (rand(1000) * 10)


corr, p = spearmanr(data1, data2)

# %%
data.corr('spearman')
# Out:
#              Пиццерия №1  Пиццерия №2
# Пиццерия №1     1.000000     0.045378
# Пиццерия №2     0.045378     1.000000

# %%
print(corr,p)
# Out:
# 0.9028676068676069 0.0

# %%
c, pe = spearmanr(data['Пиццерия №1'], data['Пиццерия №2'])

print(c, pe)
# Out:
# 0.04537815126050421 0.7957554247873968

# %%
if p>alpha:
    print(f"{p} > {alpha}. Мы не можем отвергнуть нулевую гипотезу об отсутсвии зависимости между переменными.")
else:
    print(f"{p} <= {alpha}. Мы отвергаем нулевую гипотезу об отсутсвии зависимости между переменными.")
# Out:
# 0.0 <= 0.05. Мы отвергаем нулевую гипотезу об отсутсвии зависимости между переменными.

# %%
from scipy.stats import pearsonr

c, pe = pearsonr(data['Пиццерия №1'], data['Пиццерия №2'])

print(c, pe)
# Out:
# 0.08131018627341854 0.6424058007049023

# %%
data.corr()
# Out:
#              Пиццерия №1  Пиццерия №2
# Пиццерия №1      1.00000      0.08131
# Пиццерия №2      0.08131      1.00000

# %% [markdown]
# # ANOVA тест

# %%
from scipy.stats import f_oneway

# %% [markdown]
# Однофакторный дисперсионный анализ ANOVA проверяет нулевую гипотезу о том, что две или более групп имеют одинаковое среднее значение генеральной совокупности.

# %% [markdown]
# В качестве данных возьмем информацию по размерам раковины мидий, выращенных в разных местах.

# %%
petersburg = [0.0974, 0.1352, 0.0817, 0.1016, 0.0968, 0.1064, 0.105]
magadan = [0.1033, 0.0915, 0.0781, 0.0685, 0.0677, 0.0697, 0.0764, 0.0689]
tvarminne = [0.0703, 0.1026, 0.0956, 0.0973, 0.1039, 0.1045]

# %%
_, p = f_oneway(petersburg, magadan, tvarminne)

# %%
H0 = 'Нет значимой разницы между средним размером раковины мидий в трех разных местах.'
Ha = 'Есть значимая разница между средним размером раковины мидий в трех разных местах.'

# %%
if p>alpha:
  print(f"{p} > {alpha}. Мы не можем отвергнуть нулевую гипотезу. {H0}")
else:
  print(f"{p} <= {alpha}. Мы отвергаем нулевую гипотезу. {Ha}")
# Out:
# 0.007870900547143829 <= 0.05. Мы отвергаем нулевую гипотезу. Есть значимая разница между средним размером раковины мидий в трех разных местах.

# %%
s = f_oneway(petersburg, magadan, tvarminne)

s.pvalue
# Out:
# 0.007870900547143829

# %% [markdown]
# _____

# %% [markdown]
# # Домашнее задание

# %% [markdown]
# Используя информацию по мидиям Петербурга и Магадана, которые представлены в виде двух массивов petersburg и magadan в разделе ANOVA тест, проверьте данные на нормальность и на наличие корреляции. Для этого объедините 2 массива в DataFrame. Обоснуйте выбор теста на корреляцию. Сделайте вывод по гипотезе.
#
#
# Также ответьте на вопрос:
# Какова разница в среднем размере мидии в зависимости от города-производителя. Обоснуйте выбор теста. Сделайте вывод по гипотезе.

# %% [markdown]
# # Бонус

# %% [markdown]
# Скачаем датасет, содержащий информацию по давлению 120 человек.

# %%
datata = pd.read_csv('https://raw.githubusercontent.com/yug95/MachineLearning/master/Hypothesis%20testing/blood_pressure.csv')

# %%
print('Размер выборки: ', datata.shape)
# Out:
# Размер выборки:  (120, 5)

# %%
datata.head()
# Out:
#    patient   sex agegrp  bp_before  bp_after
# 0        1  Male  30-45        143       153
# 1        2  Male  30-45        163       170
# 2        3  Male  30-45        153       168
# 3        4  Male  30-45        153       142
# 4        5  Male  30-45        146       141

# %%
datata['bp_before']
# Out:
# 0      143
# 1      163
# 2      153
# 3      153
# 4      146
#       ...
# 115    152
# 116    161
# 117    165
# 118    149
# 119    185
# Name: bp_before, Length: 120, dtype: int64

# %% [markdown]
# ## Z-тест

# %% [markdown]
# Проведем Z-тест для проверки двух независимых групп данных на равенство средних значений выборок.

# %%
from statsmodels.stats import weightstats

# %%
_ ,p = weightstats.ztest(x1=datata['bp_before'], x2=datata['bp_after'], value=0, alternative='two-sided')
print(float(p))


if p < 0.05:
    print("Мы отвергаем нулевую гипотезу об отсутсвии различий между данными.")
else:
    print("Мы не можем отвергнуть нулевую гипотезу об отсутсвии различий между данными.")
# Out:
# 0.002162306611369422
# Мы отвергаем нулевую гипотезу об отсутсвии различий между данными.

# %%
pi = weightstats.ztest(x1=datata['bp_before'], x2=datata['bp_after'], value=0, alternative='two-sided')

pi
# Out:
# (3.0669836819036274, 0.002162306611369422)

# %% [markdown]
# ## Z-тест на пропорцию

# %% [markdown]
# Z-критерий одной пропорции используется для сравнения наблюдаемой пропорции с теоретической.
#
# В этом тесте используются следующие нулевые гипотезы:
#
# $H_0: p = p_0$ (доля мужчин, предоставивших данные о своем давлении, равна гипотетической пропорции $p_0$)
#
# Альтернативная гипотеза может быть двусторонней, левосторонней или правосторонней:
#
# $H_1 (двусторонний): p ≠ p_0$ (доля мужчин не равна некоторому гипотетическому значению $p_0$)
# $H_1 (левосторонний): p < p_0$ (доля мужчин меньше некоторого гипотетического значения $p_0$)
# $H_1 (правосторонний): p > p_0$ (доля мужчин больше некоторого гипотетического значения $p_0$)

# %% [markdown]
# Предположим, что доля мужчин в нашем датачете равна 40%.
#
# $p_0$: гипотетическая доля мужчин = 0.40
#
# $x$: число мужчин в выборке мужчин: `len(data[data.sex == 'Male'])`
#
# $n$: размер выборки = `len(data)`
#
# Покажем, как использовать функцию `proportions_ztest` для выполнения  **z-теста**:

# %%
p_0 = 0.4
n = len(datata)
x = len(datata[datata.sex == 'Male'])

print(n, x)
# Out:
# 120 60

# %%
from statsmodels.stats.proportion import proportions_ztest

#perform one proportion z-test
_, p = proportions_ztest(count=x, nobs=n, value=p_0)

# %%
if p < 0.05:
    print("Мы отвергаем нулевую гипотезу о том, что доля мужчин, предоставивших данные о своем давлении, равна 40%.")
else:
    print("Мы не можем отвергнуть нулевую гипотезу.")
# Out:
# Мы отвергаем нулевую гипотезу о том, что доля мужчин, предоставивших данные о своем давлении, равна 40%.

# %%
sber_data = pd.read_csv('data/sber_data.csv')

sber_data
# Out:
#           id  full_sq  life_sq  floor              sub_area  preschool_quota  \
# 0          1       43     27.0    4.0              Bibirevo           5001.0
# 1          2       34     19.0    3.0     Nagatinskij Zaton           3119.0
# 2          3       43     29.0    2.0        Tekstil'shhiki           1463.0
# 3          4       89     50.0    9.0                Mitino           6839.0
# 4          5       77     77.0    4.0             Basmannoe           3240.0
# ...      ...      ...      ...    ...                   ...              ...
# 30466  30469       44     27.0    7.0              Otradnoe           5088.0
# 30467  30470       86     59.0    3.0              Tverskoe           1874.0
# 30468  30471       45      NaN   10.0  Poselenie Vnukovskoe              NaN
# 30469  30472       64     32.0    5.0          Obruchevskoe           2372.0
# 30470  30473       43     28.0    1.0           Novogireevo           2215.0
#
#        preschool_education_centers_raion  school_quota  \
# 0                                      5       11065.0
# 1                                      5        6237.0
# 2                                      4        5580.0
# 3                                      9       17063.0
# 4                                      7        7770.0
# ...                                  ...           ...
# 30466                                  4       12721.0
# 30467                                  4        6772.0
# 30468                                  0           NaN
# 30469                                  6        6083.0
# 30470                                  4        5824.0
#
#        school_education_centers_raion  school_education_centers_top_20_raion  \
# 0                                   5                                      0
# 1                                   8                                      0
# 2                                   7                                      0
# 3                                  10                                      0
# 4                                   9                                      0
# ...                               ...                                    ...
# 30466                               4                                      0
# 30467                               4                                      1
# 30468                               0                                      0
# 30469                               8                                      0
# 30470                               4                                      0
#
#        ...  office_km  additional_education_km  preschool_km  big_church_km  \
# 0      ...   0.637189                 0.947962      0.177975       0.625783
# 1      ...   0.688796                 1.072315      0.273345       0.967821
# 2      ...   1.543049                 0.391957      0.158072       3.178751
# 3      ...   0.934273                 0.892674      0.236455       1.031777
# 4      ...   0.077901                 0.810801      0.376838       0.378756
# ...    ...        ...                      ...           ...            ...
# 30466  ...   1.103579                 0.167718      0.349899       1.235066
# 30467  ...   0.069986                 0.086552      0.362681       0.850385
# 30468  ...   4.338453                 1.339078      1.234235       1.192543
# 30469  ...   1.204798                 1.340017      0.130667       1.644053
# 30470  ...   2.108265                 0.825811      0.378950       0.480531
#
#        church_synagogue_km  theater_km  museum_km       ecology  \
# 0                 0.628187   14.053047   7.389498          good
# 1                 0.471447    6.829889   0.709260     excellent
# 2                 0.755946    4.273200   3.156423          poor
# 3                 1.561505   16.990677  16.041521          good
# 4                 0.121681    1.112486   1.800125     excellent
# ...                    ...         ...        ...           ...
# 30466             0.612359    7.482165   4.836787          good
# 30467             0.310021    0.778428   1.450108          poor
# 30468             1.186621   13.459593   9.890758       no data
# 30469             0.476021    2.088193   4.119706  satisfactory
# 30470             0.867332    0.688707   0.127867          poor
#
#       mosque_count_1000 price_doc
# 0                     0   5850000
# 1                     0   6000000
# 2                     0   5700000
# 3                     0  13100000
# 4                     0  16331452
# ...                 ...       ...
# 30466                 0   7400000
# 30467                 0  25000000
# 30468                 0   6970959
# 30469                 0  13500000
# 30470                 0   5600000
#
# [30471 rows x 61 columns]

# %%
ser = []

for col in sber_data.columns:
    if 'metro' in col:
        sd = sber_data[col]
        ser.append(sd)

res = f_oneway(*ser)

res[1]

#ser
# Out:
# nan

# %%
ser = []

for col in sber_data.columns:
    sber_data[col]
                    
#res = f_oneway(*series)

#p = res[1]

# %%
sber_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30471 entries, 0 to 30470
# Data columns (total 61 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     30471 non-null  int64
#  1   full_sq                                30471 non-null  int64
#  2   life_sq                                24088 non-null  float64
#  3   floor                                  30304 non-null  float64
#  4   sub_area                               30471 non-null  object
#  5   preschool_quota                        23783 non-null  float64
#  6   preschool_education_centers_raion      30471 non-null  int64
#  7   school_quota                           23786 non-null  float64
#  8   school_education_centers_raion         30471 non-null  int64
#  9   school_education_centers_top_20_raion  30471 non-null  int64
#  10  hospital_beds_raion                    16030 non-null  float64
#  11  healthcare_centers_raion               30471 non-null  int64
#  12  university_top_20_raion                30471 non-null  int64
#  13  sport_objects_raion                    30471 non-null  int64
#  14  additional_education_raion             30471 non-null  int64
#  15  culture_objects_top_25_raion           30471 non-null  int64
#  16  shopping_centers_raion                 30471 non-null  int64
#  17  office_raion                           30471 non-null  int64
#  18  oil_chemistry_raion                    30471 non-null  object
#  19  railroad_terminal_raion                30471 non-null  object
#  20  nuclear_reactor_raion                  30471 non-null  object
#  21  metro_min_avto                         30471 non-null  float64
#  22  metro_km_avto                          30471 non-null  float64
#  23  metro_min_walk                         30446 non-null  float64
#  24  metro_km_walk                          30446 non-null  float64
#  25  kindergarten_km                        30471 non-null  float64
#  26  school_km                              30471 non-null  float64
#  27  park_km                                30471 non-null  float64
#  28  green_zone_km                          30471 non-null  float64
#  29  industrial_km                          30471 non-null  float64
#  30  railroad_station_walk_km               30446 non-null  float64
#  31  railroad_station_walk_min              30446 non-null  float64
#  32  public_transport_station_km            30471 non-null  float64
#  33  public_transport_station_min_walk      30471 non-null  float64
#  34  mkad_km                                30471 non-null  float64
#  35  ttk_km                                 30471 non-null  float64
#  36  sadovoe_km                             30471 non-null  float64
#  37  bulvar_ring_km                         30471 non-null  float64
#  38  kremlin_km                             30471 non-null  float64
#  39  big_road1_1line                        30471 non-null  object
#  40  big_market_km                          30471 non-null  float64
#  41  market_shop_km                         30471 non-null  float64
#  42  fitness_km                             30471 non-null  float64
#  43  swim_pool_km                           30471 non-null  float64
#  44  ice_rink_km                            30471 non-null  float64
#  45  stadium_km                             30471 non-null  float64
#  46  basketball_km                          30471 non-null  float64
#  47  hospice_morgue_km                      30471 non-null  float64
#  48  university_km                          30471 non-null  float64
#  49  workplaces_km                          30471 non-null  float64
#  50  shopping_centers_km                    30471 non-null  float64
#  51  office_km                              30471 non-null  float64
#  52  additional_education_km                30471 non-null  float64
#  53  preschool_km                           30471 non-null  float64
#  54  big_church_km                          30471 non-null  float64
#  55  church_synagogue_km                    30471 non-null  float64
#  56  theater_km                             30471 non-null  float64
#  57  museum_km                              30471 non-null  float64
#  58  ecology                                30471 non-null  object
#  59  mosque_count_1000                      30471 non-null  int64
#  60  price_doc                              30471 non-null  int64
# dtypes: float64(41), int64(14), object(6)
# memory usage: 14.2+ MB

# %%
to = sber_data.dtypes == 'object'

sber_data.dtypes[to]
# Out:
# sub_area                   object
# oil_chemistry_raion        object
# railroad_terminal_raion    object
# nuclear_reactor_raion      object
# big_road1_1line            object
# ecology                    object
# dtype: object

# %%
sber_data['ecology'].unique()
# Out:
# array(['good', 'excellent', 'poor', 'satisfactory', 'no data'],
#       dtype=object)

# %%
newsb = sber_data.copy()

newsb = newsb.drop(['id'], axis=1)

newsb
# Out:
#        full_sq  life_sq  floor              sub_area  preschool_quota  \
# 0           43     27.0    4.0              Bibirevo           5001.0
# 1           34     19.0    3.0     Nagatinskij Zaton           3119.0
# 2           43     29.0    2.0        Tekstil'shhiki           1463.0
# 3           89     50.0    9.0                Mitino           6839.0
# 4           77     77.0    4.0             Basmannoe           3240.0
# ...        ...      ...    ...                   ...              ...
# 30466       44     27.0    7.0              Otradnoe           5088.0
# 30467       86     59.0    3.0              Tverskoe           1874.0
# 30468       45      NaN   10.0  Poselenie Vnukovskoe              NaN
# 30469       64     32.0    5.0          Obruchevskoe           2372.0
# 30470       43     28.0    1.0           Novogireevo           2215.0
#
#        preschool_education_centers_raion  school_quota  \
# 0                                      5       11065.0
# 1                                      5        6237.0
# 2                                      4        5580.0
# 3                                      9       17063.0
# 4                                      7        7770.0
# ...                                  ...           ...
# 30466                                  4       12721.0
# 30467                                  4        6772.0
# 30468                                  0           NaN
# 30469                                  6        6083.0
# 30470                                  4        5824.0
#
#        school_education_centers_raion  school_education_centers_top_20_raion  \
# 0                                   5                                      0
# 1                                   8                                      0
# 2                                   7                                      0
# 3                                  10                                      0
# 4                                   9                                      0
# ...                               ...                                    ...
# 30466                               4                                      0
# 30467                               4                                      1
# 30468                               0                                      0
# 30469                               8                                      0
# 30470                               4                                      0
#
#        hospital_beds_raion  ...  office_km  additional_education_km  \
# 0                    240.0  ...   0.637189                 0.947962
# 1                    229.0  ...   0.688796                 1.072315
# 2                   1183.0  ...   1.543049                 0.391957
# 3                      NaN  ...   0.934273                 0.892674
# 4                    562.0  ...   0.077901                 0.810801
# ...                    ...  ...        ...                      ...
# 30466                  NaN  ...   1.103579                 0.167718
# 30467               1046.0  ...   0.069986                 0.086552
# 30468                  NaN  ...   4.338453                 1.339078
# 30469               3300.0  ...   1.204798                 1.340017
# 30470               1015.0  ...   2.108265                 0.825811
#
#        preschool_km  big_church_km  church_synagogue_km  theater_km  \
# 0          0.177975       0.625783             0.628187   14.053047
# 1          0.273345       0.967821             0.471447    6.829889
# 2          0.158072       3.178751             0.755946    4.273200
# 3          0.236455       1.031777             1.561505   16.990677
# 4          0.376838       0.378756             0.121681    1.112486
# ...             ...            ...                  ...         ...
# 30466      0.349899       1.235066             0.612359    7.482165
# 30467      0.362681       0.850385             0.310021    0.778428
# 30468      1.234235       1.192543             1.186621   13.459593
# 30469      0.130667       1.644053             0.476021    2.088193
# 30470      0.378950       0.480531             0.867332    0.688707
#
#        museum_km       ecology mosque_count_1000 price_doc
# 0       7.389498          good                 0   5850000
# 1       0.709260     excellent                 0   6000000
# 2       3.156423          poor                 0   5700000
# 3      16.041521          good                 0  13100000
# 4       1.800125     excellent                 0  16331452
# ...          ...           ...               ...       ...
# 30466   4.836787          good                 0   7400000
# 30467   1.450108          poor                 0  25000000
# 30468   9.890758       no data                 0   6970959
# 30469   4.119706  satisfactory                 0  13500000
# 30470   0.127867          poor                 0   5600000
#
# [30471 rows x 60 columns]
